# %% [markdown]
# #  Error Analyses of TDR Soil Moisture Sensor

# %% [markdown]
# **A validation of accuracy claims made in sales literature**

# %% [markdown]
# ![Screenshot%202022-12-01%20at%202.09.01%20PM.png](attachment:Screenshot%202022-12-01%20at%202.09.01%20PM.png)

# %% [markdown]
# ## Prepared by B. Keith Bellingham, <br />
# Soil Scientist, <br />
# September 20, 2022<br/>
# https://www.linkedin.com/in/bkbellingham/
#
# **Introduction**
#
# Time domain reflectometry (TDR) is commonly used for the determination of the volumetric soil water
# content. Monitoring soil moisture is increasingly becoming more important for irrigation,
# flood and drought risk, water resources, and climate change assessments. TDR is based on the principle
# that the velocity of an electrical pulse will slow down in the soil as the soil gets wetter. The
# travel time of the electrical pulse, T, is directly corelated to the parameter called the apparent dielectric permittivity, $K_a$ (sometimes called the relative dielectric permittivity). Knowing the time of travel of the pulse, the $K_a$ of the soil can be determined by;
#
#
# $$K_a = (cT/2L)^2$$
#
# Where c is the speed of light, and L is the path length of the waveguide. The waveguide is metal part of the sensor that is in the soil through which the electrical pulse travels before reflecting back to the sensor head.
#
# The Topp Equation, is commonly used as the soil moisture calibration for TDRs by using  the $K_a$ value to estimate soil water content;
#
# $$\theta = a + bK_a + cK_a^2 + dK_a^3$$
#
# Where a, b, c, and d, are empirical coefficients and $\theta$, is soil moisture.
#
# Soil salinity is often represented by the bulk electrical conductivity (EC) and is important for assessing seawater intrusion and poor drainage in soils. EC is measured by TDR using the impedance or shrinkage of the reflected electrical pulse. The unit for EC is micro-Siemens per cm ($\mu S/cm$)
#
# Many soil moisture sensors on the market make claims about accuracy and repeatability and it is difficult for most end users to validate such claims. In this study, ten True TDR sensors were tested in controlled conditions against NIST traceable standards in an attempt to reproduce the accuracy claims in the sales literature for the parameters of EC, $K_a$ and $\theta$.
#
# **Accuracy claims as they appear in sales literature**
#
#
# Parameter |Accuracy Stated in Sales Literature |Units
# --------:|:------------:|:-----------:
# $K_a$ | 	+/-2 |	Dielectric
# $K_a$, RMSE |	0.07 |	Dielectric
# $K_a$, Stability <3000 $\mu S/cm$ |	+/-1 |	Dielectric
# Soil Moisture RMSE |	0.07 |	%
# Soil Moisture Accuracy |	+/-2 |	%
# EC RMSE Full range |	3  | $\mu S/cm$
# EC up to 1000 $\mu S/cm$ | +/-25 | $\mu S/cm$
# EC 2500 – 6000 $\mu S/cm$ | +/-5	|%
#
#
# **Materials and Methods**
#
# The ten sensors were tested within the stated ranges. Testing methods used were similar to testing methods found in the scientific literature at room temperature.
#
# |Materials
# :--------|
# |SDI-12 Host for data collection
# |Ten SDI-12 “True” TDR Soil Moisture and EC Sensors, brand new.
# |99.9% HPLC Grade Isopropyl Alcohol with a literature dielectric content of 18.5 @25 C
# |Distilled Water with a literature dielectric constant of 78.5 at room temperature.
# |1000, 2000, 5000 micro-Siemen/cm ($\mu S/cm$) reference solutions traceable to NIST
#
#
# **About the Dataset**
#
# There are ten csv files one file for each of the ten TDR sensors tested. Three to six replicates were sampled for each on the six media types for each sensor. The sensor replicate measurements were 1 minute apart and were averaged to best represent an individual sensor’s performance. The media types tested for all ten sensors were isopropyl alcohol (IPA), distilled water, 1000, 2000, and 5000 $\mu S/cm$ reference solutions.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex

# %%
#Bring data in and make column names

df_683 = pd.read_csv('EC_683.csv')
df_684 = pd.read_csv('EC_684.csv')
df_685 = pd.read_csv('EC_685.csv')
df_686 = pd.read_csv('EC_686.csv')
df_687 = pd.read_csv('EC_687.csv')
df_688 = pd.read_csv('EC_688.csv')
df_689 = pd.read_csv('EC_689.csv')
df_690 = pd.read_csv('EC_690.csv')
df_691 = pd.read_csv('EC_691.csv')
df_692 = pd.read_csv('EC_692.csv')


df_683.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)
df_684.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)
df_685.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)
df_686.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)
df_687.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)
df_688.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)
df_689.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)
df_690.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)
df_691.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)
df_692.set_axis(['Time','VWC', 'Temp', 'Ka', 'EC', 'PoreEC'], axis=1,inplace=True)

# %%
#In IPA Media

df_683_IPA = df_683.loc[(df_683['Ka']>10) & (df_683['Ka']<30)]
df_684_IPA = df_684.loc[(df_684['Ka']>10) & (df_684['Ka']<30)]
df_685_IPA = df_685.loc[(df_685['Ka']>10) & (df_685['Ka']<30)]
df_686_IPA = df_686.loc[(df_686['Ka']>10) & (df_686['Ka']<30)]
df_687_IPA = df_687.loc[(df_687['Ka']>10) & (df_687['Ka']<30)]
df_688_IPA = df_688.loc[(df_688['Ka']>10) & (df_688['Ka']<30)]
df_689_IPA = df_689.loc[(df_689['Ka']>10) & (df_689['Ka']<30)]
df_690_IPA = df_690.loc[(df_690['Ka']>10) & (df_690['Ka']<30)]
df_691_IPA = df_691.loc[(df_691['Ka']>10) & (df_691['Ka']<30)]
df_692_IPA = df_692.loc[(df_692['Ka']>10) & (df_692['Ka']<30)]

# Ka find average in IPA for each sensor with 3 to 6 replicates. 
df_683_IPA_Ka_ave = (df_683_IPA['Ka'].mean())
df_684_IPA_Ka_ave = (df_684_IPA['Ka'].mean())
df_685_IPA_Ka_ave = (df_685_IPA['Ka'].mean())
df_686_IPA_Ka_ave = (df_686_IPA['Ka'].mean())
df_687_IPA_Ka_ave = (df_687_IPA['Ka'].mean())
df_688_IPA_Ka_ave = (df_688_IPA['Ka'].mean())
df_689_IPA_Ka_ave = (df_689_IPA['Ka'].mean())
df_690_IPA_Ka_ave = (df_690_IPA['Ka'].mean())
df_691_IPA_Ka_ave = (df_691_IPA['Ka'].mean())
df_692_IPA_Ka_ave = (df_692_IPA['Ka'].mean())


#Make a dataframe with the mean  each sensor
df_IPA = pd.DataFrame()
df_IPA['Ka_ave'] =  (df_683_IPA_Ka_ave, df_684_IPA_Ka_ave, df_685_IPA_Ka_ave, df_686_IPA_Ka_ave,
                    df_687_IPA_Ka_ave, df_688_IPA_Ka_ave, df_689_IPA_Ka_ave, df_690_IPA_Ka_ave, 
                    df_691_IPA_Ka_ave,df_692_IPA_Ka_ave) 


#Create Veriables for each calculated mean for the group of sensors in IPA 
IPA_Ka_ave = (df_IPA['Ka_ave'].mean())
IPA_Ka_std = (df_IPA['Ka_ave'].std())
df_IPA
# Out:
#       Ka_ave
# 0  13.883333
# 1  13.683333
# 2  13.733333
# 3  13.440000
# 4  13.833333
# 5  13.600000
# 6  13.550000
# 7  13.820000
# 8  13.662500
# 9  13.500000

# %%
#Ka In Distilled Water
df_683_Water = df_683.loc[(df_683['EC']<500)& (df_683['Ka']>50)]
df_684_Water = df_684.loc[(df_684['EC']<500)& (df_684['Ka']>50)]
df_685_Water = df_685.loc[(df_685['EC']<500)& (df_685['Ka']>50)]
df_686_Water = df_686.loc[(df_686['EC']<500)& (df_686['Ka']>50)]
df_687_Water = df_687.loc[(df_687['EC']<500)& (df_687['Ka']>50)]
df_688_Water = df_688.loc[(df_688['EC']<500)& (df_688['Ka']>50)] 
df_689_Water = df_689.loc[(df_689['EC']<500)& (df_689['Ka']>50)] 
df_690_Water = df_690.loc[(df_690['EC']<500)& (df_690['Ka']>50)] 
df_691_Water = df_691.loc[(df_691['EC']<500)& (df_691['Ka']>50)] 
df_692_Water = df_692.loc[(df_692['EC']<500)& (df_692['Ka']>50)] 


# Ka find Ave in Water 
df_683_Water_Ka_ave = (df_683_Water['Ka'].mean())
df_684_Water_Ka_ave = (df_684_Water['Ka'].mean())
df_685_Water_Ka_ave = (df_685_Water['Ka'].mean())
df_686_Water_Ka_ave = (df_686_Water['Ka'].mean())
df_687_Water_Ka_ave = (df_687_Water['Ka'].mean())
df_688_Water_Ka_ave = (df_688_Water['Ka'].mean())
df_689_Water_Ka_ave = (df_689_Water['Ka'].mean())
df_690_Water_Ka_ave = (df_690_Water['Ka'].mean())
df_691_Water_Ka_ave = (df_691_Water['Ka'].mean())
df_692_Water_Ka_ave = (df_692_Water['Ka'].mean())


#Make a dataframe with the mean  each sensor
df_Water = pd.DataFrame()
df_Water['Ka_ave'] =  (df_683_Water_Ka_ave, df_684_Water_Ka_ave, df_685_Water_Ka_ave, df_686_Water_Ka_ave,
                       df_687_Water_Ka_ave, df_688_Water_Ka_ave, df_689_Water_Ka_ave, df_690_Water_Ka_ave,
                       df_691_Water_Ka_ave, df_692_Water_Ka_ave) 


#Create Veriables for each calculated mean for the group of sensors 
Water_Ka_ave = (df_Water['Ka_ave'].mean())
Water_Ka_std = (df_Water['Ka_ave'].std())

#EC in Water
df_683_Water_EC_ave = (df_683_Water['EC'].mean())
df_684_Water_EC_ave = (df_684_Water['EC'].mean())
df_685_Water_EC_ave = (df_685_Water['EC'].mean())
df_686_Water_EC_ave = (df_686_Water['EC'].mean())
df_687_Water_EC_ave = (df_687_Water['EC'].mean())
df_688_Water_EC_ave = (df_688_Water['EC'].mean())
df_689_Water_EC_ave = (df_689_Water['EC'].mean())
df_690_Water_EC_ave = (df_690_Water['EC'].mean())
df_691_Water_EC_ave = (df_691_Water['EC'].mean())
df_692_Water_EC_ave = (df_692_Water['EC'].mean())



#Make a dataframe with the mean  each sensor

df_Water['EC_ave'] =  (df_683_Water_EC_ave, df_684_Water_EC_ave, df_685_Water_EC_ave, df_686_Water_EC_ave,
                       df_687_Water_EC_ave, df_688_Water_EC_ave, df_689_Water_EC_ave, df_690_Water_EC_ave, 
                       df_691_Water_EC_ave, df_692_Water_EC_ave) 


#Create Veriables for each calculated mean for the group of sensors 
Water_EC_ave = (df_Water['EC_ave'].mean())
Water_EC_std = (df_Water['EC_ave'].std())

df_Water
# Out:
#       Ka_ave    EC_ave
# 0  78.016667  1.000000
# 1  78.316667  0.833333
# 2  78.100000  1.000000
# 3  77.628571  1.000000
# 4  78.000000  2.000000
# 5  78.080000  1.200000
# 6  77.975000  2.000000
# 7  78.220000  1.000000
# 8  78.220000  1.000000
# 9  78.575000  1.000000

# %%
#1000 uS/cm
df_683_EC_One = df_683.loc[(df_683['EC']<1500)& (df_683['EC']>500)]
df_684_EC_One = df_684.loc[(df_684['EC']<1500)& (df_684['EC']>500)]
df_685_EC_One = df_685.loc[(df_685['EC']<1500)& (df_685['EC']>500)]
df_686_EC_One = df_686.loc[(df_686['EC']<1500)& (df_686['EC']>500)]
df_687_EC_One = df_687.loc[(df_687['EC']<1500)& (df_687['EC']>500)]
df_688_EC_One = df_688.loc[(df_688['EC']<1500)& (df_688['EC']>500)] 
df_689_EC_One = df_689.loc[(df_689['EC']<1500)& (df_689['EC']>500)] 
df_690_EC_One = df_690.loc[(df_690['EC']<1500)& (df_690['EC']>500)] 
df_691_EC_One = df_691.loc[(df_691['EC']<1500)& (df_691['EC']>500)] 
df_692_EC_One = df_692.loc[(df_692['EC']<1500)& (df_692['EC']>500)] 


# Ka find Ave 
df_683_EC_One_Ka_ave = (df_683_EC_One['Ka'].mean())
df_684_EC_One_Ka_ave = (df_684_EC_One['Ka'].mean())
df_685_EC_One_Ka_ave = (df_685_EC_One['Ka'].mean())
df_686_EC_One_Ka_ave = (df_686_EC_One['Ka'].mean())
df_687_EC_One_Ka_ave = (df_687_EC_One['Ka'].mean())
df_688_EC_One_Ka_ave = (df_688_EC_One['Ka'].mean())
df_689_EC_One_Ka_ave = (df_689_EC_One['Ka'].mean())
df_690_EC_One_Ka_ave = (df_690_EC_One['Ka'].mean())
df_691_EC_One_Ka_ave = (df_691_EC_One['Ka'].mean())
df_692_EC_One_Ka_ave = (df_692_EC_One['Ka'].mean())

#Make a dataframe with the mean  each sensor
df_EC_One = pd.DataFrame()
df_EC_One['Ka_ave'] =  (df_683_EC_One_Ka_ave, df_684_EC_One_Ka_ave, df_685_EC_One_Ka_ave, df_686_EC_One_Ka_ave,
                        df_687_EC_One_Ka_ave, df_688_EC_One_Ka_ave, df_689_EC_One_Ka_ave, df_690_EC_One_Ka_ave, 
                        df_691_EC_One_Ka_ave, df_692_EC_One_Ka_ave) 


#Create Veriables for each calculated mean for the group of sensors 
EC_One_Ka_ave = (df_EC_One['Ka_ave'].mean())
EC_One_Ka_std = (df_EC_One['Ka_ave'].std())


#EC
df_683_EC_One_EC_ave = (df_683_EC_One['EC'].mean())
df_684_EC_One_EC_ave = (df_684_EC_One['EC'].mean())
df_685_EC_One_EC_ave = (df_685_EC_One['EC'].mean())
df_686_EC_One_EC_ave = (df_686_EC_One['EC'].mean())
df_687_EC_One_EC_ave = (df_687_EC_One['EC'].mean())
df_688_EC_One_EC_ave = (df_688_EC_One['EC'].mean())
df_689_EC_One_EC_ave = (df_689_EC_One['EC'].mean())
df_690_EC_One_EC_ave = (df_690_EC_One['EC'].mean())
df_691_EC_One_EC_ave = (df_691_EC_One['EC'].mean())
df_692_EC_One_EC_ave = (df_692_EC_One['EC'].mean())


#Make a dataframe with the mean  each sensor

df_EC_One['EC_ave'] =  (df_683_EC_One_EC_ave, df_684_EC_One_EC_ave, df_685_EC_One_EC_ave, df_686_EC_One_EC_ave,
                        df_687_EC_One_EC_ave, df_688_EC_One_EC_ave, df_689_EC_One_EC_ave, df_690_EC_One_EC_ave,
                        df_691_EC_One_EC_ave, df_692_EC_One_EC_ave) 


#Create Veriables for each calculated mean for the group of sensors 
EC_One_EC_ave = (df_EC_One['EC_ave'].mean())
EC_One_EC_std = (df_EC_One['EC_ave'].std())


df_EC_One
# Out:
#       Ka_ave       EC_ave
# 0  77.000000   982.200000
# 1  77.533333   995.166667
# 2  77.633333  1004.666667
# 3  77.040000   969.700000
# 4  77.075000   972.500000
# 5  78.000000   985.200000
# 6  77.325000   975.500000
# 7  75.760000   977.600000
# 8  77.650000   982.333333
# 9  77.500000   993.750000

# %%
#2000 uS/cm
df_683_EC_Two = df_683.loc[(df_683['EC']<3500)& (df_683['EC']>1200)]
df_684_EC_Two = df_684.loc[(df_684['EC']<3500)& (df_684['EC']>1200)]
df_685_EC_Two = df_685.loc[(df_685['EC']<3500)& (df_685['EC']>1200)]
df_686_EC_Two = df_686.loc[(df_686['EC']<3500)& (df_686['EC']>1200)]
df_687_EC_Two = df_687.loc[(df_687['EC']<3500)& (df_687['EC']>1200)]
df_688_EC_Two = df_688.loc[(df_688['EC']<3500)& (df_688['EC']>1200)] 
df_689_EC_Two = df_689.loc[(df_689['EC']<3500)& (df_689['EC']>1200)] 
df_690_EC_Two = df_690.loc[(df_690['EC']<3500)& (df_690['EC']>1200)] 
df_691_EC_Two = df_691.loc[(df_691['EC']<3500)& (df_691['EC']>1200)] 
df_692_EC_Two = df_692.loc[(df_692['EC']<3500)& (df_692['EC']>1200)] 


# Ka find Ave 
df_683_EC_Two_Ka_ave = (df_683_EC_Two['Ka'].mean())
df_684_EC_Two_Ka_ave = (df_684_EC_Two['Ka'].mean())
df_685_EC_Two_Ka_ave = (df_685_EC_Two['Ka'].mean())
df_686_EC_Two_Ka_ave = (df_686_EC_Two['Ka'].mean())
df_687_EC_Two_Ka_ave = (df_687_EC_Two['Ka'].mean())
df_688_EC_Two_Ka_ave = (df_688_EC_Two['Ka'].mean())
df_689_EC_Two_Ka_ave = (df_689_EC_Two['Ka'].mean())
df_690_EC_Two_Ka_ave = (df_690_EC_Two['Ka'].mean())
df_691_EC_Two_Ka_ave = (df_691_EC_Two['Ka'].mean())
df_692_EC_Two_Ka_ave = (df_692_EC_Two['Ka'].mean())



#Make a dataframe with the mean  each sensor
df_EC_Two = pd.DataFrame()
df_EC_Two['Ka_ave'] =  (df_683_EC_Two_Ka_ave, df_684_EC_Two_Ka_ave, df_685_EC_Two_Ka_ave, df_686_EC_Two_Ka_ave,
                        df_687_EC_Two_Ka_ave, df_688_EC_Two_Ka_ave, df_689_EC_Two_Ka_ave, df_690_EC_Two_Ka_ave, 
                        df_691_EC_Two_Ka_ave, df_692_EC_Two_Ka_ave) 


#Create Veriables for each calculated mean for the group of sensors 
EC_Two_Ka_ave = (df_EC_Two['Ka_ave'].mean())
EC_Two_Ka_std = (df_EC_Two['Ka_ave'].std())


#EC
df_683_EC_Two_EC_ave = (df_683_EC_Two['EC'].mean())
df_684_EC_Two_EC_ave = (df_684_EC_Two['EC'].mean())
df_685_EC_Two_EC_ave = (df_685_EC_Two['EC'].mean())
df_686_EC_Two_EC_ave = (df_686_EC_Two['EC'].mean())
df_687_EC_Two_EC_ave = (df_687_EC_Two['EC'].mean())
df_688_EC_Two_EC_ave = (df_688_EC_Two['EC'].mean())
df_689_EC_Two_EC_ave = (df_689_EC_Two['EC'].mean())
df_690_EC_Two_EC_ave = (df_690_EC_Two['EC'].mean())
df_691_EC_Two_EC_ave = (df_691_EC_Two['EC'].mean())
df_692_EC_Two_EC_ave = (df_692_EC_Two['EC'].mean())



#Make a dataframe with the mean  each sensor

df_EC_Two['EC_ave'] =  (df_683_EC_Two_EC_ave, df_684_EC_Two_EC_ave, df_685_EC_Two_EC_ave, df_686_EC_Two_EC_ave,
                        df_687_EC_Two_EC_ave, df_688_EC_Two_EC_ave, df_689_EC_Two_EC_ave, df_690_EC_Two_EC_ave,
                        df_691_EC_Two_EC_ave, df_692_EC_Two_EC_ave) 


#Create Veriables for each calculated mean for the group of sensors 
EC_Two_EC_ave = (df_EC_Two['EC_ave'].mean())
EC_Two_EC_std = (df_EC_Two['EC_ave'].std())

df_EC_Two
# Out:
#       Ka_ave       EC_ave
# 0  75.960000  1929.000000
# 1  77.740000  2045.000000
# 2  76.700000  2049.250000
# 3  77.633333  1975.833333
# 4  76.766667  1957.666667
# 5  78.500000  1982.000000
# 6  76.725000  1959.250000
# 7  77.500000  2027.000000
# 8  78.266667  2013.833333
# 9  76.850000  1946.000000

# %%
#5000 uS/cm
df_683_EC_Five = df_683.loc[(df_683['EC']>3500)]
df_684_EC_Five = df_684.loc[(df_684['EC']>3500)]
df_685_EC_Five = df_685.loc[(df_685['EC']>3500)]
df_686_EC_Five = df_686.loc[(df_686['EC']>3500)]
df_687_EC_Five = df_687.loc[(df_687['EC']>3500)]
df_688_EC_Five = df_688.loc[(df_688['EC']>3500)] 
df_689_EC_Five = df_689.loc[(df_689['EC']>3500)] 
df_690_EC_Five = df_690.loc[(df_690['EC']>3500)] 
df_691_EC_Five = df_691.loc[(df_691['EC']>3500)] 
df_692_EC_Five = df_692.loc[(df_692['EC']>3500)] 


# Ka find Ave 
df_683_EC_Five_Ka_ave = (df_683_EC_Five['Ka'].mean())
df_684_EC_Five_Ka_ave = (df_684_EC_Five['Ka'].mean())
df_685_EC_Five_Ka_ave = (df_685_EC_Five['Ka'].mean())
df_686_EC_Five_Ka_ave = (df_686_EC_Five['Ka'].mean())
df_687_EC_Five_Ka_ave = (df_687_EC_Five['Ka'].mean())
df_688_EC_Five_Ka_ave = (df_688_EC_Five['Ka'].mean())
df_689_EC_Five_Ka_ave = (df_689_EC_Five['Ka'].mean())
df_690_EC_Five_Ka_ave = (df_690_EC_Five['Ka'].mean())
df_691_EC_Five_Ka_ave = (df_691_EC_Five['Ka'].mean())
df_692_EC_Five_Ka_ave = (df_692_EC_Five['Ka'].mean())



#Make a dataframe with the mean  each sensor
df_EC_Five = pd.DataFrame()
df_EC_Five['Ka_ave'] =  (df_683_EC_Five_Ka_ave, df_684_EC_Five_Ka_ave, df_685_EC_Five_Ka_ave, df_686_EC_Five_Ka_ave,
                         df_687_EC_Five_Ka_ave, df_688_EC_Five_Ka_ave, df_689_EC_Five_Ka_ave, df_690_EC_Five_Ka_ave,
                         df_691_EC_Five_Ka_ave, df_692_EC_Five_Ka_ave) 


#Create Veriables for each calculated mean for the group of sensors 
EC_Five_Ka_ave = (df_EC_Five['Ka_ave'].mean())
EC_Five_Ka_std = (df_EC_Five['Ka_ave'].std())


#EC
df_683_EC_Five_EC_ave = (df_683_EC_Five['EC'].mean())
df_684_EC_Five_EC_ave = (df_684_EC_Five['EC'].mean())
df_685_EC_Five_EC_ave = (df_685_EC_Five['EC'].mean())
df_686_EC_Five_EC_ave = (df_686_EC_Five['EC'].mean())
df_687_EC_Five_EC_ave = (df_687_EC_Five['EC'].mean())
df_688_EC_Five_EC_ave = (df_688_EC_Five['EC'].mean())
df_689_EC_Five_EC_ave = (df_689_EC_Five['EC'].mean())
df_690_EC_Five_EC_ave = (df_690_EC_Five['EC'].mean())
df_691_EC_Five_EC_ave = (df_691_EC_Five['EC'].mean())
df_692_EC_Five_EC_ave = (df_692_EC_Five['EC'].mean())



#Make a dataframe with the mean  each sensor

df_EC_Five['EC_ave'] =  (df_683_EC_Five_EC_ave, df_684_EC_Five_EC_ave, df_685_EC_Five_EC_ave, df_686_EC_Five_EC_ave,
                        df_687_EC_Five_EC_ave, df_688_EC_Five_EC_ave, df_689_EC_Five_EC_ave, df_690_EC_Five_EC_ave, 
                        df_691_EC_Five_EC_ave, df_692_EC_Five_EC_ave) 




#Create Veriables for each calculated mean for the group of sensors 
EC_Five_EC_ave = (df_EC_Five['EC_ave'].mean())
EC_Five_EC_std = (df_EC_Five['EC_ave'].std())
df_EC_Five
# Out:
#       Ka_ave       EC_ave
# 0  83.150000  4156.333333
# 1  82.957143  4537.857143
# 2  81.000000  4545.600000
# 3  83.620000  4251.400000
# 4  81.150000  4179.250000
# 5  83.733333  4239.666667
# 6  80.920000  4215.200000
# 7  81.580000  4455.600000
# 8  84.475000  4443.250000
# 9  81.720000  4265.600000

# %%
Main_TDR = pd.DataFrame({'Ave':[IPA_Ka_ave, Water_Ka_ave,
                                EC_One_Ka_ave, EC_One_EC_ave,
                                EC_Two_Ka_ave, EC_Two_EC_ave,
                                EC_Five_Ka_ave, EC_Five_EC_ave                          
                                ],
                        
                         'STD':[IPA_Ka_std, Water_Ka_std, 
                                EC_One_Ka_std, EC_One_EC_std, 
                                EC_Two_Ka_std, EC_Two_EC_std,
                                EC_Five_Ka_std,  EC_Five_EC_std                                
                                 ]},
                          
                          index=['IPA 99%', 'Water',  
                                  '1000 uS/cm Ka', '1000 uS/cm EC',
                                  '2000 uS/cm Ka', '2000 uS/cm EC', 
                                  '5000 uS/cm Ka', '5000 uS/cm EC']) 
Main_TDR
# Out:
#                        Ave         STD
# IPA 99%          13.670583    0.149083
# Water            78.113190    0.248293
# 1000 uS/cm Ka    77.251667    0.612386
# 1000 uS/cm EC   983.861667   11.075922
# 2000 uS/cm Ka    77.264167    0.794389
# 2000 uS/cm EC  1988.483333   42.638388
# 5000 uS/cm Ka    82.430548    1.303119
# 5000 uS/cm EC  4328.975714  150.121628

# %%
#RMSE

            
EC_EC_RMSE = (((Water_EC_ave - 0)**2 + (EC_Five_EC_ave - 5000)**2 + (EC_Two_EC_ave - 2000)**2 +
            (EC_One_EC_ave - 1000)**2)**0.5)/4        
EC_Ka_RMSE = (((IPA_Ka_ave - 18.5)**2 + (Water_Ka_ave - 78.5)**2 + (EC_One_Ka_ave - 78.5)**2 +
            (EC_Two_Ka_ave - 78.5)**2 + (EC_Five_Ka_ave - 78.5)**2)**0.5)/5


EC_EC_ME = ((Water_EC_ave - 0) + (EC_Five_EC_ave - 5000) + (EC_Two_EC_ave - 2000) +
            (EC_One_EC_ave - 1000))/4        
EC_Ka_ME = ((IPA_Ka_ave - 18.5) + (Water_Ka_ave - 78.5) + (EC_One_Ka_ave - 78.5) +
            (EC_Two_Ka_ave - 78.5) + (EC_Five_Ka_ave - 78.5))/5


EC_Ka_RMSE_2 = (((IPA_Ka_ave - 18.5)**2 + (Water_Ka_ave - 78.5)**2 + (EC_One_Ka_ave - 78.5)**2 +
            (EC_Two_Ka_ave - 78.5)**2)**0.5)/4



print("The RMSE of the EC is: ", EC_EC_RMSE ,"MicroSiemens per cm")
print("The RMSE of the Ka is: ", EC_Ka_RMSE, "Dielectric Units") 

print("The Mean Error of the EC is: ", EC_EC_ME ,"MicroSiemens per cm")
print("The Mean Error of the Ka is: ", EC_Ka_ME, "Dielectric Units") 

print("RMSE of Ka under 3000uS/cm  ", EC_Ka_RMSE_2)
# Out:
# The RMSE of the EC is:  167.82954884408903 MicroSiemens per cm
# The RMSE of the Ka is:  1.2962671279096365 Dielectric Units
# The Mean Error of the EC is:  -174.36898809523814 MicroSiemens per cm
# The Mean Error of the Ka is:  -0.7539690476190476 Dielectric Units
# RMSE of Ka under 3000uS/cm   1.2883736619978612

# %%
df_683_IPA_VWC_ave = (df_683_IPA['VWC'].mean())
df_684_IPA_VWC_ave = (df_684_IPA['VWC'].mean())
df_685_IPA_VWC_ave = (df_685_IPA['VWC'].mean())
df_686_IPA_VWC_ave = (df_686_IPA['VWC'].mean())
df_687_IPA_VWC_ave = (df_687_IPA['VWC'].mean())
df_688_IPA_VWC_ave = (df_688_IPA['VWC'].mean())
df_689_IPA_VWC_ave = (df_689_IPA['VWC'].mean())
df_690_IPA_VWC_ave = (df_690_IPA['VWC'].mean())
df_691_IPA_VWC_ave = (df_691_IPA['VWC'].mean())
df_692_IPA_VWC_ave = (df_692_IPA['VWC'].mean())


#Make a dataframe with the mean  each sensor
df_IPA = pd.DataFrame()
df_IPA['VWC_ave'] =  (df_683_IPA_VWC_ave, df_684_IPA_VWC_ave, df_685_IPA_VWC_ave, df_686_IPA_VWC_ave,
                    df_687_IPA_VWC_ave, df_688_IPA_VWC_ave, df_689_IPA_VWC_ave, df_690_IPA_VWC_ave, 
                    df_691_IPA_VWC_ave,df_692_IPA_VWC_ave) 


#Create Veriables for each calculated mean for the group of sensors in IPA 
IPA_VWC_ave = (df_IPA['VWC_ave'].mean())
IPA_VWC_std = (df_IPA['VWC_ave'].std())


print("For a dielectric contant of 18.5, the TDR estamates a water content of ",IPA_VWC_ave, "", "std", IPA_VWC_std)
# Out:
# For a dielectric contant of 18.5, the TDR estamates a water content of  25.43175  std 0.2512666830036448

# %%
#Topp Equation 

K = 18.5
topp_wfv = (-530 + 292*K - 5.5*K**2 + .043*K**3)/100
print("The soil moisture when Ka = 18.5 is ", topp_wfv,"%")

K = IPA_Ka_ave
topp_wfv_TDR = (-530 + 292*K - 5.5*K**2 + .043*K**3)/100

print("Output from TDR soil moisture when soil moisture is 32.6%", topp_wfv_TDR)


dif = topp_wfv - topp_wfv_TDR
print("The error between sensor output and the  Topp equation is", dif,"%", "at about 30% moisture")
# Out:
# The soil moisture when Ka = 18.5 is  32.61884875 %
# Output from TDR soil moisture when soil moisture is 32.6% 25.438011362222614
# The error between sensor output and the  Topp equation is 7.180837387777384 % at about 30% moisture

# %%
x = [0, 1000, 2000, 5000]
y_1 = [Water_EC_ave, EC_One_EC_ave, EC_Two_EC_ave, EC_Five_EC_ave]
x_6 = 0, 1000, 2000, 6000
y_6 = 0, 1000, 2000, 6000
#x refers to 0 and y refers to 1


fig_4 = plt.figure(figsize=(8,8))
axes_4 = fig_4.add_axes([0,0,1,1]) #this means you want the whole array
axes_4.set_xlabel(r'EC Referance $\mu S/cm$',fontsize=15)
axes_4.set_ylabel(r'EC Responce from Sensor $\mu S/cm$',fontsize=15)
axes_4.set_title('EC Sensor Responce Vs. Referance',fontsize=18)




axes_4.plot(x, y_1, label='Sensor Responce')
axes_4.plot(x_6, y_6, label = 'Referance')
#axes_4.legend(loc="upper left")
axes_4.legend(loc='best',fontsize=15)



axes_4.annotate('Actual EC Range', xy=(2000, 2000),fontsize=15, xytext=(1000, 2700),
                arrowprops=dict(facecolor='black', shrink=0.5))

axes_4.annotate('', xy=(3000, 3000), xytext=(2000, 3000),
                arrowprops=dict(facecolor='black', shrink=0.09))


axes_4.annotate('EC Range Stated in Sales Litrature', xy=(6000, 6000),fontsize=15, xytext=(2700, 5800),
                arrowprops=dict(facecolor='black', shrink=0.09))

axes_4.annotate(r'Sensor under estamates EC by 700 $\mu S/cm$', xy=(5000, 4200),fontsize=15, xytext=(4500, 3000),
                arrowprops=dict(facecolor='black', shrink=0.09))
# Out:
# Text(4500, 3000, 'Sensor under estamates EC by 700 $\\mu S/cm$')

# %% [markdown]
# **Results and Discussion**
#
# The averages and standard deviations for EC and $K_a$ are shown in the table.
#
# Media | Average | Standard Deviation
# ----------:|:-----------:|:--------:
# IPAA 99%|13.67|0.15
# Water| 78.11|  0.25
# 1000 $\mu S/cm$  $K_a$ |77.25|0.61
# 1000 $\mu S/cm$  EC|983.86|11.075922
# 2000 $\mu S/cm$  $K_a$ |77.26|0.79
# 2000 $\mu S/cm$  EC|1988.48|42.64
# 5000 $\mu S/cm$  $K_a$ |82.43|1.30
# 5000 $\mu S/cm$  EC|4328.98|150.12
#
#
#
#
# The RMSE in the $K_a$ was determined to be 1.29. The bias/mean error of -0.75 represents an underestimation of the sensor technology within the stated measurement range.
#
# The dielectric constant of isopropyl alcohol is 18.5 and according to the Topp equation, a dielectric constant of 18.5 would represent a soil moisture of 32.6%.  The TDR technology under estimated the $K_a$ in IPA with average value of 13.6 and thus generates a soil moisture of 25.4%. The value of 25.4% was also reproduced when applying  a $K_a$ value of 13.6 to the Topp equation.
#
#
# Parameter |Accuracy Stated in Sales Literature |Measured Accuracy from this study |Units
# --------:|:------------:|:-----------:|:---------:
# $K_a$ | 	+/-2 |5 when $K_a$ = 18|	Dielectric
# $K_a$ RMSE |	0.07 |1.29|	Dielectric
# $K_a$ Stability <3000 $\mu S/cm$ |	+/-1 |NA|	Dielectric
# Soil Moisture RMSE |	0.07 |NA|	%
# Soil Moisture Accuracy |	+/-2 |-7.2 when soil moisture is near 30%|	%
# EC RMSE Full range |	3  |167| $\mu S/cm$
# EC up to 1000 $\mu S/cm$ | +/-25 |-17 at 1000 $\mu S/cm$ | $\mu S/cm$
# EC 2500 – 6000 $\mu S/cm$ | +/-5	|-11 at 5000  $\mu S/cm$|%

# %% [markdown]
# **Conclusion**
#
# Ten True TDR sensors were tested in controlled conditions using testing methods consistent with the scientific literature. The Accuracy claims on the sales literature were not reproduced in this study. The  $K_a$ outputs  had a RMSE 20 times higher than what was stated in the sales literature. The sensor is underestimating soil moisture by 7% when soil moisture values are near 30%, and showed an error than 3 times higher than what is reported in the sales literature.  The  measured  upper range of the EC was determined to be from 3000 to 5000 $\mu S/cm$ in aqueous solution while the sales literature claims 6000 $\mu S/cm$. The full range RMSE of the EC was found to be 167 $\mu S/cm$ while sales literature claims a value of 3. The sales literate claims an accuracy of 5% from 2500 to 6000 $\mu S/cm$  but has an 11% accuracy at 5000 $\mu S/cm$.

# %% [markdown]
# **References**
#
# Blonquist, J. M., Jr., S. B. Jones, D.A. Robinson. 2005. "Standardizing Characterization of Electromagnetic Water Content Sensors: Part 2. Evaluation of Seven Sensing Systems." Vadose Zone J. (4): 1059-1069.
#
# Dalton, F.N., Van Genuchten, M. Th. 1986. "The Time-Domain Reflectometery Method for Measuring Soil Water Content and Salinity." Geoderma 38: 237-250.
#
# Jones, S. B., J. M. Blonquist, Jr., D.A. Robinson, V. Philip Rasmussen, and D. Or. 2005. "Standardizing Characterization of Electromagnetic Water Content Sensors: Part 1:
# Methodology." Vadose Zone J. 4: 1028-1058.
#
# Topp, G.C., J.L. Davis, and A.P. Annan. 1980. "Electromagnetic determination of soil water content: Measurement in coaxial transmission lines." Water Resour. Res. 16: 574-582.
#
# True TDR Data Sheet.  model 315N, SDI-12, Acclima inc. 2022,  https://acclima.com/wp-content/uploads/Acclima-TDR315N-Data-Sheet-3.pdf
